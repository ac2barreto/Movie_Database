# %%
import pandas as pd
import requests
import sqlite3


filename = '../Project3 copy/imdb_clean.csv'  

data = pd.read_csv(filename)

df = pd.read_csv(filename)

df=df.rename(columns={"Unnamed: 0":"id"})

df
# Out:
#        id                     title              director  release_year  \
# 0       0  The Shawshank Redemption        Frank Darabont          1994
# 1       1             The Godfather  Francis Ford Coppola          1972
# 2       1             The Godfather  Francis Ford Coppola          1972
# 3       2           The Dark Knight     Christopher Nolan          2008
# 4       2           The Dark Knight     Christopher Nolan          2008
# ...   ...                       ...                   ...           ...
# 2527  998         The Invisible Man           James Whale          1933
# 2528  998         The Invisible Man           James Whale          1933
# 2529  999                  Cell 211         Daniel Monzón          2009
# 2530  999                  Cell 211         Daniel Monzón          2009
# 2531  999                  Cell 211         Daniel Monzón          2009
#
#       runtime   genre  rating  metascore  gross(M)
# 0         142   Drama     9.3         82     28.34
# ...

# %%
conn = sqlite3.connect('movies.db')

# %%
#dupes=df.groupby("id")['title']

df_clean=df["title"].unique().tolist()
#df_clean2=df["id"].unique().tolist()
df2=df.drop_duplicates(subset=["name"])
df2.title.value_counts()
# Out:
# title
# Beauty and the Beast               2
# Scarface                           2
# All Quiet on the Western Front     2
# Drishyam 2                         2
# The Girl with the Dragon Tattoo    2
#                                   ..
# Everything's Gonna Be Great        1
# Sarfarosh                          1
# Anand                              1
# Dune                               1
# Cell 211                           1
# Name: count, Length: 994, dtype: int64

# %%
df2.loc[df2["title"]=="Scarface"]
# Out:
#        id     title        director  release_year  runtime   genre  rating  \
# 240    94  Scarface  Brian De Palma          1983      170   Crime     8.3
# 2268  898  Scarface    Howard Hawks          1932       93  Action     7.7
#
#       metascore  gross(M)
# 240          65      45.6
# 2268         90       0.0

# %%
df2["name"]=df2["title"]+", "+(df2["release_year"]).astype(str)
df2
# Out:
# /var/folders/x7/484zgwwx2tq0wv8v5_65n4pr0000gn/T/ipykernel_2849/3329015628.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["name"]=df2["title"]+", "+(df2["release_year"]).astype(str)
#        id                     title              director  release_year  \
# 0       0  The Shawshank Redemption        Frank Darabont          1994
# 1       1             The Godfather  Francis Ford Coppola          1972
# 3       2           The Dark Knight     Christopher Nolan          2008
# 6       3          Schindler's List      Steven Spielberg          1993
# 9       4              12 Angry Men          Sidney Lumet          1957
# ...   ...                       ...                   ...           ...
# ...

# %%
df.groupby("id")

# %%
movies
--
id int PK
title varchar(50)	
director varchar(50)	 
release_year int	
runtime int
genre varchar(20)
rating float	
metascore int
gross(M) float 


movies
--
id int PK 
title varchar(50) FK
director varchar(50)	 
release_year int	
runtime int
rating float	
metascore int
gross(M) float 

genre
--
id int PK FK  >- movies.id
title varchar(50) FK >- movies.title	
genre varchar(20)
